# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127627_americas_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0           93763.0            48981.0          44782.0   18.184992
# 1           93219.0            48708.0          44511.0   12.115000
# 2           92664.0            48428.0          44236.0   12.160000
# 3           92117.0            48156.0          43961.0   11.485000
# 4           91626.0            47911.0          43715.0   10.816000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.828165                       11.0                  20.153997
# 1    6.365000                       11.0                  20.153997
# 2    5.961000                       11.0                  20.153997
# 3    5.865000                       11.0                  20.153997
# 4    5.787000                       11.0                  20.153997
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     17.004881                             8.655858
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1204, 26)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.204000e+03       1.204000e+03     1.204000e+03  1204.000000
# mean       2.126095e+07       1.075849e+07     1.050246e+07    18.184992
# std        5.505953e+07       2.791240e+07     2.714762e+07     5.728701
# min        1.510100e+04       7.336000e+03     7.765000e+03     5.900000
# 25%        1.091660e+05       5.645700e+04     5.554250e+04    13.767000
# 50%        3.422497e+06       1.764235e+06     1.658096e+06    17.602500
# 75%        1.194908e+07       5.975354e+06     5.995499e+06    22.027250
# max        3.332876e+08       1.682662e+08     1.650213e+08    37.349000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1204.000000                1204.000000                1204.000000
# mean      6.828165                  10.879921                  20.153997
# std       1.721987                   2.510386                   3.128110
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# - The range between the minimum and maximum values of the population in the data is large. The data has a high degree of variability.
#
# - In non-population-related features, when the mean is fairly close to the median, the data may be considered normally distributed. Because my data collection is incomplete, missing values are replaced with the mean value.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED

# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# Create a new dataframe
sum_total_population_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
sum_total_population_df["Sum.Total Population"] = cleaned_df.groupby("Country")["Total Population"].sum()

# Set the index as a column - countries
sum_total_population_df["Country"] = sum_total_population_df.index

# Drop the index
sum_total_population_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Sum Total Population
sum_total_population_df.sort_values("Sum.Total Population", inplace=True, ascending=False)


top10_largest_sum_total_population_df = sum_total_population_df.head(10)

top10_largest_sum_total_population_df
# Out:
#     Sum.Total Population        Country
# 39          8.497052e+09  United States
# 8           5.383162e+09         Brazil
# 27          3.084068e+09         Mexico
# 13          1.230773e+09       Colombia
# 1           1.134079e+09      Argentina
# 10          9.423726e+08         Canada
# 31          8.146559e+08           Peru
# 41          7.623301e+08  Venezuela, RB
# 12          4.721390e+08          Chile
# 18          4.110567e+08        Ecuador

# %%
result = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ cleaned_df và top10_largest_sum_total_population_df dựa trên cột 'country'
result = cleaned_df.merge(top10_largest_sum_total_population_df, on='Country')

# In ra dữ liệu kết quả
result

# create a copy
df_copy = result.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Sum.Total Population'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
# - When the conutry population is large. The features 'GDP in USD', 'Net income from Abroad', 'Agriculture value added (in USD)', 'Electric Power Consumption (kWh per capita)' will increase. As the population grows, it will boost the total income, income from abroad, and aid economic growth. In addition, a larger population requires ensuring domestic food sources, contributing to economic, energy, and agricultural growth.
# - The features that could be dropped due to weak correlation are: 'Compulsory Education Dur.', 'National Income per Capita', 'Literacy rate'

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
top10_smallest_sum_total_population_df = sum_total_population_df.tail(10)
top10_smallest_sum_total_population_df
# Out:
#     Sum.Total Population                   Country
# 42             3020547.0     Virgin Islands (U.S.)
# 2              2708201.0                     Aruba
# 0              2324697.0       Antigua and Barbuda
# 16             1945076.0                  Dominica
# 6              1778695.0                   Bermuda
# 20             1579434.0                 Greenland
# 11             1444524.0            Cayman Islands
# 33             1304144.0       St. Kitts and Nevis
# 38              813057.0  Turks and Caicos Islands
# 9               710980.0    British Virgin Islands

# %%
result_top10_smallest = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ cleaned_df và top10_smallest_sum_total_population_df dựa trên cột 'country'
result_top10_smallest = cleaned_df.merge(top10_smallest_sum_total_population_df, on='Country')

# In ra dữ liệu kết quả
result_top10_smallest

# create a copy
df_copy = result_top10_smallest.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Sum.Total Population'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
# - The feature 'Unemployment(%)' will be low, while 'Employment in Agriculture(%)' will be high. The two features, 'Employment in Agriculture(%)' and 'Female Employment in Agriculture(%)', exhibit a strong correlation with each other.
# - The features that could be dropped due to weak correlation are:'National Income per Capita', Electric Power Consumption(kWH per capita), 'Fossil Fuel Consumption (%)', 'Literacy rate'

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate    Country
# 22       28.940357  Guatemala
# 24       27.961714      Haiti
# 25       27.421750   Honduras
# 7        26.289464    Bolivia
# 5        24.881107     Belize

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate              Country
# 16       10.081113             Dominica
# 24        9.555292                Haiti
# 40        9.377899              Uruguay
# 33        9.339327  St. Kitts and Nevis
# 4         9.075256             Barbados

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# - Countries with high birth rates and low death rates will have a very large workforce in the future, contributing significantly to economic development.
#
# - Haiti is a country with a high birth rate, but their death rate is not low. Therefore, the workforce will increase at a slower pace.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
# **A possible question is:** How does the correlation between features change in the top 10 countries with the HIGHEST GDP Per Capita?
#
# **Answering this question will** we might see how features interaction with each other when the GDP Per Capita is large.
#
# **How we answer this question**: we will consider the Average GDP Per Capita for countries across all the year. The GDP Per Capita = (GDP in USD / Total Population)

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Create a copy of the DataFrame
new_cleaned_df = cleaned_df.copy()

new_cleaned_df['GDP Per Capita'] = new_cleaned_df['GDP in USD'] / new_cleaned_df['Total Population']

# Create a new dataframe
avg_GDP_Per_Capita_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_GDP_Per_Capita_df["Avg.GDP Per Capita"] = new_cleaned_df.groupby("Country")["GDP Per Capita"].mean()

# Set the index as a column - countries
avg_GDP_Per_Capita_df["Country"] = avg_GDP_Per_Capita_df.index

# Drop the index
avg_GDP_Per_Capita_df.reset_index(drop=True, inplace=True)

avg_GDP_Per_Capita_df.sort_values("Avg.GDP Per Capita", inplace=True, ascending=False)


top10_largest_avg_GDP_Per_Capita_df = avg_GDP_Per_Capita_df.head(10)

top10_largest_avg_GDP_Per_Capita_df
# Out:
#     Avg.GDP Per Capita                   Country
# 9         2.039477e+07    British Virgin Islands
# 38        6.394852e+06  Turks and Caicos Islands
# 11        5.315056e+06            Cayman Islands
# 42        1.516886e+06     Virgin Islands (U.S.)
# 20        3.515044e+05                 Greenland
# 2         1.916343e+05                     Aruba
# 6         8.625779e+04                   Bermuda
# 39        4.842669e+04             United States
# 10        3.856522e+04                    Canada
# 3         2.632183e+04              Bahamas, The

# %%
result = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ new_cleaned_df và top10_largest_avg_GDP_Per_Capita_df dựa trên cột 'country'
result = new_cleaned_df.merge(top10_largest_avg_GDP_Per_Capita_df, on='Country')

# In ra dữ liệu kết quả
result

# create a copy
df_copy = result.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Avg.GDP Per Capita'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Comment :**
# - GDP Per Capita is an indicator that reflects the wealth of the population in a country. GDP Per Capita usually has a direct correlation with GDP in USD and an inverse relationship with Total Population.
# - From the chart, we can observe that as GDP Per Capita increases (indicating a wealthier population), the birth rate rises, and the death rate decreases. Employment in various sectors and the primary completion rate are likely to increase

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
# **A possible question is:** How does the correlation between features change in the top 15 countries with the HIGHEST National Income per Capita (Adjusted net national income per capita (annual % growth))?
#
# **Answering this question will** we might see how features interaction with each other when the Income per Capita is large.
#
# **How we answer this question**: we will consider the Average Income per Capita for countries across all the year.
#
#
# **Note**: In worldbank, National Income per Capita is Adjusted net national income per capita (annual % growth)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Create a new dataframe
avg_national_income_per_Capita_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_national_income_per_Capita_df["Avg.National Income per Capita"] = cleaned_df.groupby("Country")["National Income per Capita"].mean()

# Set the index as a column - countries
avg_national_income_per_Capita_df["Country"] = avg_national_income_per_Capita_df.index

# Drop the index
avg_national_income_per_Capita_df.reset_index(drop=True, inplace=True)

avg_national_income_per_Capita_df.sort_values("Avg.National Income per Capita", inplace=True, ascending=False)


top15_smallest_avg_national_income_per_Capita_df = avg_national_income_per_Capita_df.tail(15)

top15_smallest_avg_national_income_per_Capita_df
# Out:
#     Avg.National Income per Capita                 Country
# 6                         1.521022                 Bermuda
# 9                         1.521022  British Virgin Islands
# 16                        1.521022                Dominica
# 39                        1.466726           United States
# 10                        1.334547                  Canada
# 8                         1.120787                  Brazil
# 22                        1.045896               Guatemala
# 18                        0.970947                 Ecuador
# 25                        0.940550                Honduras
# 1                         0.854721               Argentina
# 19                        0.510858             El Salvador
# 3                         0.450459            Bahamas, The
# 26                        0.410257                 Jamaica
# 27                        0.251841                  Mexico
# 5                        -0.693060                  Belize

# %%
result = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ cleaned_df và top15_smallest_avg_national_income_per_Capita_df dựa trên cột 'country'
result = cleaned_df.merge(top15_smallest_avg_national_income_per_Capita_df, on='Country')

# In ra dữ liệu kết quả
result

# create a copy
df_copy = result.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Avg.National Income per Capita'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Comment :**
# - National Income per Capita reflects a country's economic growth and development.
# - From the chart, we can observe that the National Income per Capita index is independent of other features. The reason for this can be divided into two categories:
#     + Being a poor, slowly developing country.
#     + Being a country that has passed a stage of development, their resources are so extensive that it makes the National Income per Capita small

# %% [markdown]
# ## Making your own question 03?

# %% [markdown]
# **YOUR ANSWER HERE**
# **A possible question is:** How does the correlation between features change in the top 15 countries with the HIGHEST GDP in USD?
#
# **Answering this question will** we might see how features interaction with each other when the GDP in USD is large.
#
# **How we answer this question**: we will consider the Average GDP in USD for countries across all the year.

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Create a new dataframe
avg_GDP_in_USD_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_GDP_in_USD_df["Avg.GDP in USD"] = cleaned_df.groupby("Country")['GDP in USD'].mean()

# Set the index as a column - countries
avg_GDP_in_USD_df["Country"] = avg_GDP_in_USD_df.index

# Drop the index
avg_GDP_in_USD_df.reset_index(drop=True, inplace=True)

avg_GDP_in_USD_df.sort_values("Avg.GDP in USD", inplace=True, ascending=False)


top15_largest_avg_GDP_in_USD_df = avg_GDP_in_USD_df.head(15)

top15_largest_avg_GDP_in_USD_df
# Out:
#     Avg.GDP in USD                   Country
# 39    1.494372e+13             United States
# 8     1.442673e+12                    Brazil
# 10    1.326516e+12                    Canada
# 27    9.560535e+11                    Mexico
# 9     5.000622e+11    British Virgin Islands
# 1     3.790670e+11                 Argentina
# 41    2.893579e+11             Venezuela, RB
# 13    2.218153e+11                  Colombia
# 11    2.170648e+11            Cayman Islands
# 12    1.813154e+11                     Chile
# 42    1.634514e+11     Virgin Islands (U.S.)
# 31    1.318047e+11                      Peru
# 38    1.077781e+11  Turks and Caicos Islands
# 15    8.964961e+10                      Cuba
# 32    8.578200e+10               Puerto Rico

# %%
result = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ cleaned_df và top15_largest_avg_GDP_in_USD_df dựa trên cột 'country'
result = cleaned_df.merge(top15_largest_avg_GDP_in_USD_df, on='Country')

# In ra dữ liệu kết quả
result

# create a copy
df_copy = result.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Avg.GDP in USD'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Comment :**
# - GDP in USD correlates with many other features.
# - From the chart, we can see that the GDP in USD is high when Total Population, Net income from Abroad, Agriculture value added (in USD), Electric Power Consumption (kWH per capita) are high.
# - The GDP in USD is high when the features Employment in Industry(%) and Employment in Agriculture(%) are low. This is true because these are large countries applying a lot of technology, science, and techniques in the industry and agriculture sectors, reducing the number of laborers.

# %% [markdown]
# ## Making your own question 04?

# %% [markdown]
# **YOUR ANSWER HERE**
# **A possible question is:** How does the correlation between features change in the top 15 countries with the LOWEST Unemployment Rate?
#
# **Answering this question will** we might see how features interaction with each other when the Unemployment Rate is small.
#
# **How we answer this question**: we will consider the Average Unemployment Rate for countries across all the year.

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Create a new dataframe
avg_unemployment_rate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_unemployment_rate_df["Avg.Unemployment Rate"] = cleaned_df.groupby("Country")['Unemployment(%)'].mean()

# Set the index as a column - countries
avg_unemployment_rate_df["Country"] = avg_unemployment_rate_df.index

# Drop the index
avg_unemployment_rate_df.reset_index(drop=True, inplace=True)

avg_unemployment_rate_df.sort_values("Avg.Unemployment Rate", inplace=True, ascending=False)


top15_smallest_avg_unemployment_rate_df = avg_unemployment_rate_df.tail(15)

top15_smallest_avg_unemployment_rate_df
# Out:
#     Avg.Unemployment Rate              Country
# 37               7.232714  Trinidad and Tobago
# 26               7.173179              Jamaica
# 17               6.394571   Dominican Republic
# 28               6.125714            Nicaragua
# 29               6.102036               Panama
# 19               5.714000          El Salvador
# 30               5.700214             Paraguay
# 39               5.695750        United States
# 25               5.017179             Honduras
# 31               4.256929                 Peru
# 18               4.234929              Ecuador
# 27               4.074214               Mexico
# 15               3.206393                 Cuba
# 7                2.993071              Bolivia
# 22               2.845214            Guatemala

# %%
result = pd.DataFrame()
# Sử dụng merge để kết hợp dữ liệu từ cleaned_df và top15_smallest_avg_unemployment_rate_df dựa trên cột 'country'
result = cleaned_df.merge(top15_smallest_avg_unemployment_rate_df, on='Country')

# In ra dữ liệu kết quả
result

# create a copy
df_copy = result.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country', 'Avg.Unemployment Rate'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Comment :**
# - Unemployment(%) is high when the features Employment in Industry(%) and Employment in Agriculture(%) are low.
# - From the chart, we can observe that the Unemployment(%) index has little dependency on other features. The reason for this is that countries always aim to maintain Unemployment(%) at a stable level. Unemployment(%) is considered good when it's neither too high nor too low.
# - Unemployment(% ) can indicate the economic situation of a country, whether it is good or bad. If it exceeds 7%, it is considered to be very poor.
