# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def collect_data(course_urls_file):
    # Initialize lists to store data
    sku_list = []
    name_list = []
    price_list = []
    in_stock_list = []
    categories_list = []
    tags_list = []

    # Read the links from the file
    with open(course_urls_file, 'r') as file:
        urls = file.read().splitlines()

    # Loop through the URLs and scrape data
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            

            # Extract data from the webpage
            sku = soup.find('span', class_='sku').text.strip()
            print(sku)
            
            name = soup.find('h1').text.strip()
            
            #price = soup.find('h1', class_='price').text.strip().split()[1]
            price_element = soup.find('p', class_='price')
            span_contents = price_element.find('span', class_='woocommerce-Price-amount').contents
            price = span_contents[1].strip()
            
            in_stock = int(soup.find('p', class_='stock').text.strip().split()[0])
            
            categories = soup.find('span', class_='posted_in').text.strip().split(': ')[1]
            print(categories)
            
            
            tags = soup.find('span', class_='tagged_as').text.strip().split(': ')[1]
            print(tags)
            

            # Append data to lists
            sku_list.append(sku)
            name_list.append(name)
            price_list.append(price)
            in_stock_list.append(in_stock)
            categories_list.append(categories)
            tags_list.append(tags)

    # Create a DataFrame from the collected data
    data = {
        'SKU': sku_list,
        'Name': name_list,
        'Price': price_list,
        'InStock': in_stock_list,
        'Categories': categories_list,
        'Tags': tags_list
    }
    df = pd.DataFrame(data)

    return df

# Usage example:
if __name__ == "__main__":
    course_urls_file = "pokemon1.txt"
    pokemon_data = collect_data(course_urls_file)
    pokemon_data.to_csv("pokemon_data.csv", index=False)
# Out:
# 4391
# Pokemon, Seed
# bulbasaur, Overgrow, Seed

# %%
import time
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
BASE_URL = 'http://api.worldbank.org/v2/'
COUNTRIES = ["US", "IN", "CN", "JP", "CA", "GB", "ZA"]
INDICATORS = ['SP.POP.TOTL',
             'SP.POP.TOTL.FE.IN',
             'SP.POP.TOTL.MA.IN',
             'SP.DYN.CBRT.IN',
             'SP.DYN.CDRT.IN',
             'SP.DYN.LE00.MA.IN',
             'SP.DYN.LE00.FE.IN',
             'SE.PRM.ENRR',
             'SE.TER.ENRR',
             'SE.PRM.CMPT.ZS',
             'SE.ADT.1524.LT.ZS']

#TODO (option)
# If you need other initializations

# %%
import xml.etree.ElementTree as ET

# Đăng ký namespace 'wb' với đường dẫn tới nó
ET.register_namespace('wb', 'http://www.worldbank.org')

def collect_data(countryCode, per_page, start_year, end_year):

    #TODO
    data = pd.DataFrame()
    for indicator in INDICATORS:
        # Construct the API URL for the specific country and indicator
        url = f"{BASE_URL}countries/{countryCode}/indicators/{indicator}"
        #?per_page={per_page}&date={start_year}:{end_year}
        print(url)    
        
        # Make a GET request to the World Bank API
        response = requests.get(url)
        # Tách các dòng
        lines = response.text.splitlines()
        
        # Lấy tất cả dòng từ dòng thứ hai trở đi
        new_response_text = '\n'.join(lines[1:])
        
        
        if response.status_code == 200:
            # Phân tích dữ liệu XML
            root = ET.ElementTree(ET.fromstring(new_response_text))
            #root = tree.getroot()
            
            
            print(1)
            
            # Khởi tạo mảng để lưu giá trị wb:value
            values = []

            # Lặp qua tất cả các phần tử wb:data
            for data_element in root.find(".//wb:data"):
                value_element = data_element.find("wb:value")
                if value_element is not None:
                    values.append(value_element.text)

            # In mảng giá trị
            print(values)                  
            
            
    
    return data

nhapdata = collect_data(countryCode = "US", per_page = 100, start_year = 2000, end_year = 2003)
print(nhapdata)
# Out:
# http://api.worldbank.org/v2/countries/US/indicators/SP.POP.TOTL
# 1
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[47], line 49
#     nhapdata = collect_data(countryCode = "US", per_page = 100, start_year = 2000, end_year = 2003)
#
#   Cell In[47], line 37 in collect_data
#     for data_element in root.find(".//wb:data"):
#
#   File ~\anaconda3\lib\xml\etree\ElementTree.py:625 in find
#     return self._root.find(path, namespaces)
#
#   File ~\anaconda3\lib\xml\etree\ElementPath.py:405 in find
#     return next(iterfind(elem, path, namespaces), None)
#
#   File ~\anaconda3\lib\xml\etree\ElementPath.py:384 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File ~\anaconda3\lib\xml\etree\ElementPath.py:185 in prepare_descendant
#     token = next()
#
# ...

# %%
def Generate_Countries_Dataset(countryCode_list):
    data = pd.DataFrame()
    for countryCode in countryCode_list:
        data = pd.concat([data, collect_data(countryCode = countryCode, per_page = 100, start_year = 2000, end_year = 2022)], axis=0)
    return data

# %%
#TEST
data_countries = Generate_Countries_Dataset(COUNTRIES)
assert data_countries.shape == (161, 13)

# %%
import xml.etree.ElementTree as ET

# Dữ liệu XML của bạn
xml_data = """
<wb:data xmlns:wb="http://www.worldbank.org" page="1" pages="2" per_page="50" total="63" sourceid="2" lastupdated="2023-09-19">
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2022</wb:date>
<wb:value>333287557</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2021</wb:date>
<wb:value>332031554</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2020</wb:date>
<wb:value>331511512</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2019</wb:date>
<wb:value>328329953</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2018</wb:date>
<wb:value>326838199</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2017</wb:date>
<wb:value>325122128</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
<wb:data>
<wb:indicator id="SP.POP.TOTL">Population, total</wb:indicator>
<wb:country id="US">United States</wb:country>
<wb:countryiso3code>USA</wb:countryiso3code>
<wb:date>2016</wb:date>
<wb:value>323071755</wb:value>
<wb:unit/>
<wb:obs_status/>
<wb:decimal>0</wb:decimal>
</wb:data>
"""

# Parse dữ liệu XML
root = ET.fromstring(xml_data)

# Tạo một mảng để lưu trữ giá trị wb:value
values = []

# Lặp qua tất cả các phần tử wb:data và trích xuất giá trị wb:value
for data_element in root.findall('.//wb:data'):
    value_element = data_element.find('wb:value')
    if value_element is not None:
        value = value_element.text
        values.append(value)

# In ra mảng giá trị
print(values)
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[49], line 79
#     root = ET.fromstring(xml_data)
#
#   File ~\anaconda3\lib\xml\etree\ElementTree.py:1343 in XML
#     return parser.close()
#
#   File <string>
# ParseError: no element found: line 73, column 0
